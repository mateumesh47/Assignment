# %%
#1.a
import numpy as np
arr1=np.array([[1,2,3],[1,2,3]])
print("Method 1 Output:")
print(arr1)
# Out:
# Method 1 Output:
# [[1 2 3]
#  [4 5 6]]

# %%
#1.b
arr2=np.full((2,3),[1,2,3])
print("Method 2 Output:")
print(arr2)
# Out:
# Method 2 Output:
# [[1 2 3]
#  [1 2 3]]

# %%
#1.c
arr3=np.ones((2,3))*[1,2,3]
print("Method 3 Output:")
print(arr3)
# Out:
# Method 3 Output:
# [[1. 2. 3.]
#  [1. 2. 3.]]

# %%
#1.d
arr4=np.tile([1,2,3],(2,1))
print("Method 4 Output:")
print(arr4)
# Out:
# Method 4 Output:
# [[1 2 3]
#  [1 2 3]]

# %%
#2
arr1=np.linspace(1,100,10)
arr2=arr1.reshape(2,5)
print("\nOrignal array:")
print(arr1)
print("\nReshaped 2D Array:")
print(arr2)
# Out:
# Orignal array:
# [  1.  12.  23.  34.  45.  56.  67.  78.  89. 100.]
#
# Reshaped 2D Array:
# [[  1.  12.  23.  34.  45.]
#  [ 56.  67.  78.  89. 100.]]

# %%
#3.a
'''
np.array:used to create an numpy array from input.If the input is already an array, it creates a copy
np.asarray:Converts the input to a NumPy array but doesn’t create a copy if the input is already an array
np.asanyarray:Similar to np.asarray() but if the input is already a specialized array

'''

#3.b
'''
Deep Copy:Creates a new object and recursively copies all the contents. The new object is completely independent of the original
Shallow Copy: Creates a new object, but the contentsstill reference the original objects. Changes to the contents of the new object will reflect in the original object and vice versa.
'''

# %%
#4
arr1=np.random.uniform(5,20,(3,3))
arr2=np.round(arr1,2)

print("\nRandom Array:")
print(arr1)

print("\nRounded Array:")
print(arr2)
# Out:
# Random Array:
# [[ 8.25684954  9.80713749 11.05177655]
#  [14.65497718  8.18089836 16.82767317]
#  [ 7.69640314 12.20987226 18.40219735]]
#
# Rounded Array:
# [[ 8.26  9.81 11.05]
#  [14.65  8.18 16.83]
#  [ 7.7  12.21 18.4 ]]

# %%
#5
arr1 = np.random.randint(1,11,(5,6))

print("Random Array:")
print(arr1)

#a
even= arr1[arr1 % 2 == 0]
print("\nEven Integers:")
print(even)

#b
odd=arr1[arr1 % 2 != 0]
print("\nOdd Integers:")
print(odd)
# Out:
# Random Array:
# [[5 3 5 4 7 6]
#  [3 6 9 8 8 4]
#  [7 6 2 6 3 9]
#  [1 8 8 3 2 3]
#  [2 7 4 9 1 3]]
#
# Even Integers:
# [4 6 6 8 8 4 6 2 6 8 8 2 2 4]
#
# Odd Integers:
# [5 3 5 7 3 9 7 3 9 1 3 3 7 9 1 3]

# %%
#6
arr=np.random.randint(1,11,(3,3,3))

print("3D Array:")
print(arr)

#a
max=np.argmax(arr,axis=2)
print("\nIndices of Maximum Values Along Each Depth Level (Third Axis):")
print(max)

#b
multiplied_array=arr*arr
print("\nElement-wise Multiplied Array:")
print(multiplied_array)
# Out:
# 3D Array:
# [[[ 5  4  5]
#   [ 8  7  9]
#   [ 3  9  6]]
#
#  [[ 3  7  4]
#   [ 2 10  8]
#   [ 3  9  8]]
#
#  [[ 1  8 10]
#   [ 8  3  7]
#   [ 3  8  6]]]
#
# Indices of Maximum Values Along Each Depth Level (Third Axis):
# [[0 2 1]
#  [1 1 1]
#  [2 0 1]]
#
# Element-wise Multiplied Array:
# [[[ 25  16  25]
#   [ 64  49  81]
#   [  9  81  36]]
#
#  [[  9  49  16]
#   [  4 100  64]
#   [  9  81  64]]
#
#  [[  1  64 100]
#   [ 64   9  49]
#   [  9  64  36]]]

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-cad59454-15ca-4a94-bbd4-17b0b7527f3a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cad59454-15ca-4a94-bbd4-17b0b7527f3a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/People Data.csv')
df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
#7
import re
df['Phone']=df['Phone'].astype(str).apply(lambda x:re.sub(r'\D','',x))
df['Phone']=pd.to_numeric(df['Phone'],errors='coerce')

print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1000 non-null   int64
#  1   User Id        1000 non-null   object
#  2   First Name     1000 non-null   object
#  3   Last Name      1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Email          1000 non-null   object
#  6   Phone          979 non-null    float64
#  7   Date of birth  1000 non-null   object
#  8   Job Title      1000 non-null   object
#  9   Salary         1000 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 78.2+ KB
# None
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# ...

# %%
import pandas as pd
import numpy as np

def convert_to_phone(value):
    if pd.isna(value):
        return np.nan
    else:
        return str(int(value))
df["Phone"] = df["Phone"].apply(convert_to_phone)

df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email             Phone Date of birth  \
# 0              pwarner@example.org        8571398239    27-01-2014
# 1    fergusonkatherine@example.net               NaN    26-07-1931
# 2              fhoward@example.org        5997820605    25-11-2013
# ...

# %%
#8.a
df1=pd.read_csv('/content/People Data.csv', skiprows=50)
df1
# Out:
#        50  afF3018e9cdd1dA     George    Mercer  Female  \
# 0      51  CccE5DAb6E288e5         Jo    Zavala    Male
# 1      52  DfBDc3621D4bcec     Joshua     Carey  Female
# 2      53  f55b0A249f5E44D     Rickey     Hobbs  Female
# 3      54  Ed71DcfaBFd0beE      Robyn    Reilly    Male
# 4      55  FDaFD0c3f5387EC  Christina    Conrad    Male
# ..    ...              ...        ...       ...     ...
# 945   996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 946   997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 947   998  2adde51d8B8979E      Cathy  Mckinney  Female
# 948   999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 949  1000  8b756f6231DDC6e        Lee      Tran  Female
#
#     douglascontreras@example.net    +1-326-669-0118x4341  11-09-1941  \
# 0           pamela64@example.net  001-859-448-9935x54536  23-11-1992
# 1      dianashepherd@example.net    001-274-739-8470x814  07-01-1915
# 2      ingramtiffany@example.org        241.179.9509x498  01-07-1910
# ...

# %%
#8.b
df2=df[['Last Name','Gender','Email','Phone','Salary']]
df2
# Out:
#     Last Name  Gender                          Email             Phone  Salary
# 0     Mahoney    Male            pwarner@example.org        8571398239   90000
# 1      Rivers  Female  fergusonkatherine@example.net               NaN   80000
# 2      Lowery  Female            fhoward@example.org        5997820605   50000
# 3      Hooper    Male          zjohnston@example.com               NaN   65000
# 4        Rice  Female               elin@example.net    39041716353010  100000
# ..        ...     ...                            ...               ...     ...
# 995    Bryant  Female         lyonsdaisy@example.net         217752933   90000
# 996     Barry  Female        dariusbryan@example.com    11497107799721   50000
# 997  Mckinney  Female         georgechan@example.org  1750774412833265   60000
# 998    Phelps    Male            wanda04@example.net        9152922254  100000
# 999      Tran  Female        deannablack@example.org    79752542467259   90000
#
# [1000 rows x 5 columns]

# %%
#8.c
df.head(10)
# Out:
#    Index          User Id First Name Last Name  Gender  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# 5      6  aF75e6dDEBC5b66     Sherry  Caldwell    Male
# 6      7  efeb05c7Cc94EA3     Ernest   Hoffman    Male
# 7      8  fb1BF3FED57E9d7      Doris  Andersen    Male
# 8      9  421fAB9a3b98F30     Cheryl      Mays    Male
# 9     10  4A42Fe10dB717CB      Harry  Mitchell    Male
#
#                            Email           Phone Date of birth  \
# 0            pwarner@example.org      8571398239    27-01-2014
# 1  fergusonkatherine@example.net             NaN    26-07-1931
# 2            fhoward@example.org      5997820605    25-11-2013
# 3          zjohnston@example.com             NaN    17-11-2012
# ...

# %%
#8.d
sal=df['Salary']
sal.tail(5)
# Out:
# 995     90000
# 996     50000
# 997     60000
# 998    100000
# 999     90000
# Name: Salary, dtype: int64

# %%
#9
df3= df[
    (df['Last Name'].str.contains('Duke', regex=True)) &
    (df['Gender']=='Female') &
    (df['Salary']<85000)
]
df3
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email             Phone Date of birth  \
# 45        diana26@example.net  1366475860704350    13-10-1934
# 210       robin78@example.com        7404340212    21-09-1935
# 457  perryhoffman@example.org    19035960995489    11-02-1997
# 729   kevinkramer@example.net        9826926257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %%
#10
random=pd.Series(np.random.randint(1,7,size=35))
df4=pd.DataFrame(random.values.reshape(7,5))
df4
# Out:
#    0  1  2  3  4
# 0  2  5  6  2  4
# 1  2  1  3  1  1
# 2  4  2  5  6  2
# 3  5  1  2  3  6
# 4  3  2  5  6  6
# 5  2  4  1  1  1
# 6  5  5  5  4  1

# %%
#11.a
series1=pd.Series(np.random.randint(10,51,size=50))
series1
# Out:
# 0     27
# 1     12
# 2     43
# 3     29
# 4     34
# 5     29
# 6     31
# 7     31
# 8     22
# 9     28
# 10    32
# 11    25
# 12    36
# 13    28
# 14    19
# 15    13
# 16    32
# 17    21
# 18    16
# 19    36
# 20    33
# 21    45
# 22    29
# 23    13
# 24    31
# 25    42
# 26    21
# 27    46
# 28    26
# 29    41
# 30    36
# 31    10
# 32    14
# 33    46
# 34    38
# 35    48
# 36    26
# 37    23
# 38    39
# 39    20
# 40    13
# 41    35
# 42    41
# 43    25
# 44    35
# 45    45
# 46    38
# 47    18
# 48    24
# 49    17
# dtype: int64

# %%
#11.b
series2=pd.Series(np.random.randint(100,1001,size=50))
series2
# Out:
# 0     612
# 1     644
# 2     771
# 3     653
# 4     907
# 5     984
# 6     990
# 7     581
# 8     409
# 9     368
# 10    680
# 11    864
# 12    407
# 13    271
# 14    658
# 15    281
# 16    833
# 17    293
# 18    778
# 19    992
# 20    173
# 21    966
# 22    375
# 23    182
# 24    239
# 25    932
# 26    961
# 27    263
# 28    666
# 29    525
# 30    865
# 31    727
# 32    244
# 33    826
# 34    898
# 35    311
# 36    670
# 37    925
# 38    587
# 39    349
# 40    775
# 41    404
# 42    642
# 43    256
# 44    845
# 45    935
# 46    802
# 47    899
# 48    851
# 49    964
# dtype: int64

# %%
#11.c
df5=pd.DataFrame({'col1':series1,'col2':series2})
df5
# Out:
#     col1  col2
# 0     27   612
# 1     12   644
# 2     43   771
# 3     29   653
# 4     34   907
# 5     29   984
# 6     31   990
# 7     31   581
# 8     22   409
# 9     28   368
# 10    32   680
# 11    25   864
# 12    36   407
# 13    28   271
# 14    19   658
# 15    13   281
# 16    32   833
# 17    21   293
# 18    16   778
# 19    36   992
# 20    33   173
# 21    45   966
# 22    29   375
# 23    13   182
# 24    31   239
# 25    42   932
# 26    21   961
# 27    46   263
# 28    26   666
# 29    41   525
# 30    36   865
# 31    10   727
# 32    14   244
# 33    46   826
# 34    38   898
# 35    48   311
# 36    26   670
# 37    23   925
# 38    39   587
# 39    20   349
# 40    13   775
# 41    35   404
# 42    41   642
# 43    25   256
# 44    35   845
# 45    45   935
# 46    38   802
# 47    18   899
# 48    24   851
# 49    17   964

# %%
#12.abc
df6=df.drop(columns=['Email','Phone','Date of birth'])
df7=df6.dropna()
df7
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
#13.a
import numpy as np
import matplotlib.pyplot as plt

x=np.random.rand(100)
y=np.random.rand(100)
plt.scatter(x,y,color='red',marker='o',label='Scatter points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Advanced Scatter Plot of Random Values')
plt.legend()

# %%
#13.b
plt.axhline(y=0.5,color='blue',linestyle='--',label='y = 0.5')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# %%
#13.c
plt.axvline(x=0.5,color='green',linestyle=':',label='x = 0.5')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# %%
#13.d
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
#13.e
plt.title('Advanced Scatter Plot of Random Values')
# Out:
# Text(0.5, 1.0, 'Advanced Scatter Plot of Random Values')

# %%
#13.f
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#14
date=pd.date_range(start='2024-01-01',periods=30,freq='D')
temperature=np.random.uniform(low=15,high=30,size=30)
humidity=np.random.uniform(low=40,high=90,size=30)

df=pd.DataFrame({
    'Date':date,
    'Temperature':temperature,
    'Humidity':humidity
})

fig, ax1=plt.subplots()

ax1.plot(df['Date'],df['Temperature'],'r-',label='Temperature')
ax1.set_ylabel('Temperature (°C)',color='red')
ax1.set_xlabel('Date')


ax2 = ax1.twinx()
ax2.plot(df['Date'],df['Humidity'],'b-',label='Humidity')
ax2.set_ylabel('Humidity (%)',color='blue')

plt.title('Temperature and Humidity Over Time')
# Out:
# Text(0.5, 1.0, 'Temperature and Humidity Over Time')

# %%
#15 16
from scipy.stats import norm

data=np.random.normal(loc=0,scale=1,size=1000)
plt.hist(data,bins=30,density=True,alpha=0.6,color='b',label='Histogram')

xmin,xmax=plt.xlim()
x=np.linspace(xmin,xmax,100)
p=norm.pdf(x,np.mean(data),np.std(data))
plt.plot(x,p,'k',linewidth=2,label='PDF')

plt.xlabel('Value')
plt.ylabel('Frequency/Probability')
plt.title('Histogram with PDF Overlay')
# Out:
# Text(0.5, 1.0, 'Histogram with PDF Overlay')

# %%
#17
import seaborn as sns

x=np.random.randn(100)
y=np.random.randn(100)

df=pd.DataFrame({'X':x,'Y':y})
df['Quadrant'] = np.where((df['X'] >= 0) & (df['Y'] >= 0),'Quadrant 1',
                   np.where((df['X'] < 0) & (df['Y'] >= 0),'Quadrant 2',
                   np.where((df['X'] < 0) & (df['Y'] < 0),'Quadrant 3','Quadrant 4')))

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='X',y='Y',hue='Quadrant',palette='viridis',s=100,alpha=0.7)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadrant-wise Scatter Plot')
plt.legend(title='Quadrant')

plt.show()

# %%
#18
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()

x=np.linspace(0,2*np.pi,100)
y=np.sin(x)

p=figure(title="Sine Wave Function", x_axis_label='x', y_axis_label='sin(x)',width=800,height=400)
p.line(x,y,line_width=2,color='blue',legend_label='Sine Wave')

p.grid.grid_line_color='gray'
p.grid.grid_line_alpha=0.5

show(p)
# Out:
#   <div id="e36e8e10-6cce-48c5-9eb9-1d552b47d442" data-root-id="p1001" style="display: contents;"></div>

# %%
#19
from bokeh.models import ColumnDataSource, HoverTool
output_notebook()

categories=['Category A','Category B','Category C','Category D','Category E']
values=np.random.randint(10,100,size=len(categories))

data=pd.DataFrame({'Category':categories,'Value': values})
p=figure(x_range=data['Category'],title="Random Categorical Bar Chart",x_axis_label='Category',y_axis_label='Value',width=800,height=400)
p.vbar(x='Category',top='Value',source=data,width=0.5,color='blue',legend_label='Values')

hover = HoverTool()
hover.tooltips = [("Category","@Category"),("Value","@Value")]
p.add_tools(hover)

show(p)
# Out:
#   <div id="e65766c0-edcd-41a5-9e34-6e37782d0812" data-root-id="p1098" style="display: contents;"></div>

# %%
#20
import plotly.graph_objects as go
x=np.linspace(0,10,100)
y=np.random.random(100)

fig = go.Figure()
fig.add_trace(go.Scatter(x=x,y=y,mode='lines',name='Line'))
fig.update_layout(title='Simple Line Plot',xaxis_title='X-axis',yaxis_title='Y-axis')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#21
labels=['Category A','Category B','Category C','Category D','Category E']
values=np.random.randint(10,100,size=len(labels))

fig=go.Figure(data=[go.Pie(labels=labels,values=values,textinfo='label+percent',hole=0.3)])
fig.update_layout(title='Interactive Pie Chart')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
